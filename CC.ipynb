# %%
import graph
import random
import DPATrial as DPA
import ER 
import nodeOff
import CC
import networkx as nx

# %%
m=1
nodes = [i for i in range(20)]

# %%
#G=DPA.DpaGraph(m,nodes)
G1 = ER.ERGraph(nodes,2)
G1.plotGraph()

# %%
nodeOff.randomOffNode(G1)
print CC.ConnectedComponets(G1)
G1.plotGraph()
# Out:
# nodo eliminato:  18
# [[15, 5, 12, 0], [11], [13], [14], [16]]
