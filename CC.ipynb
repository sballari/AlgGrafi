# %%
import graph
import random
import DPATrial as DPA
import ER 
import nodeOff
import CC

# %%
m=1
nodes = [i for i in range(20)]

# %%
#G=DPA.DpaGraph(m,nodes)
G1 = DPA.DpaGraph(3,nodes)
G1.plotGraph()

# %%
nodeOff.randomOffNode(G1)
arrayCC=CC.ConnectedComponets(G1)
print arrayCC
print 'resilienza:',CC.resilienza(arrayCC)
G1.plotGraph()
# Out:
# nodo eliminato:  2
# [[10, 1], [4], [8], [15], [17]]
# resilienza: 0.333333333333
